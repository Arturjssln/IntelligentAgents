# %% [markdown]
# # Analysis of population

# %%
import matplotlib.pyplot as plt
import pandas as pd
from os import listdir
from os.path import isfile, join
# %matplotlib inline

# %%
path = "../log/"
filenames = [f for f in listdir(path) if isfile(join(path, f))]
print("There are {} file(s)".format(len(filenames)))
# Out:
# There are 7 file(s)

# %%
dfs = [pd.read_csv("../log/"+filename) for filename in filenames]
if dfs != []:
    print(dfs[0].head(10))
# Out:
#    Rabbits  Grass
# 0       20     99
# 1       20    101
# 2       20    101
# 3       20    104
# 4       20    106
# 5       20     99
# 6       20    100
# 7       20     99
# 8       20     99
# 9       20     98

# %%
for filename, df in zip(filenames, dfs):
    fig, ax = plt.subplots()
    ax2 = ax.twinx()
    ax.plot(df.index.to_numpy(), df["Rabbits"].to_numpy(), color='gray')
    ax.set_ylabel("Number of Rabbits",color="gray")
    ax2.plot(df.index.to_numpy(), df["Grass"].to_numpy(), color='green')
    ax2.set_ylabel("Grass quantity",color="green")
    plt.title(filename)
    plt.show()
